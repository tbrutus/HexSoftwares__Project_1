# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("C:/Users/BRUTUS/Downloads/SALESDATAA.csv")

# %%
#1 understand the dat

# %%
data.head()
# Out:
#             PoB PoB Office PoB Online / Offline Countries   PoB Countries  \
# 0  CH Chevrolet      PEACH                         ONLINE  CH - CHEVROLET
# 1  CH Chevrolet      PEACH                         ONLINE  CH - CHEVROLET
# 2  CH Chevrolet      PEACH                         ONLINE  CH - CHEVROLET
# 3  CH Chevrolet      PEACH                         ONLINE  CH - CHEVROLET
# 4      LE Lexus      MANGO                         ONLINE      LE - LEXUS
#
#     Month Period     Carrier Contribution  NTR EUR 2022  NTR BGT 2022  \
# 0  22-Jan    YTD  AIR FRANCE            H        100761        135853
# 1  22-Jan    YTD  AIR FRANCE            L        269144        484569
# 2  22-Jan    YTD         KLM            H             0             0
# 3  22-Jan    YTD         KLM            L           216             0
# 4  22-Jan    YTD  AIR FRANCE            H        221642        226573
#
#    PaxKM EUR 2022  PaxKM BGT 2022
# 0          467398          510334
# ...

# %%
data.tail()
# Out:
#                 PoB PoB Office PoB Online / Offline Countries  \
# 1099  VW Volkswagen     ORANGE                         ONLINE
# 1100      TO Toyota       PEAR                         ONLINE
# 1101      TO Toyota       PEAR                         ONLINE
# 1102      TO Toyota       PEAR                         ONLINE
# 1103      TO Toyota       PEAR                         ONLINE
#
#         PoB Countries   Month Period     Carrier Contribution  NTR EUR 2022  \
# 1099  VW - VOLKSWAGEN  22-Dec    DTE         KLM            L        676698
# 1100      TO - TOYOTA  22-Dec    DTE  AIR FRANCE            H       1995994
# 1101      TO - TOYOTA  22-Dec    DTE  AIR FRANCE            L       3449125
# 1102      TO - TOYOTA  22-Dec    DTE         KLM            H       1079397
# 1103      TO - TOYOTA  22-Dec    DTE         KLM            L       2985600
#
#       NTR BGT 2022  PaxKM EUR 2022  PaxKM BGT 2022
# 1099        676698        10872231        10872231
# ...

# %%
data.shape
# Out:
# (1104, 12)

# %%
data.describe()
# Out:
#        NTR EUR 2022  NTR BGT 2022  PaxKM EUR 2022  PaxKM BGT 2022
# count  1.104000e+03  1.104000e+03    1.104000e+03    1.104000e+03
# mean   2.493024e+05  2.560412e+05    3.672059e+06    3.724103e+06
# std    5.931697e+05  6.124148e+05    1.129238e+07    1.130387e+07
# min    0.000000e+00 -1.677000e+03    0.000000e+00   -4.722900e+04
# 25%    0.000000e+00  0.000000e+00    0.000000e+00    0.000000e+00
# 50%    3.496500e+03  2.534500e+03    2.992450e+04    1.671300e+04
# 75%    1.249995e+05  1.590430e+05    1.090852e+06    1.122685e+06
# max    5.404647e+06  5.404647e+06    9.899839e+07    9.899839e+07

# %%
data.columns
# Out:
# Index(['PoB', 'PoB Office', 'PoB Online / Offline Countries', 'PoB Countries',
#        'Month', 'Period', 'Carrier', 'Contribution', 'NTR EUR 2022',
#        'NTR BGT 2022', 'PaxKM EUR 2022', 'PaxKM BGT 2022'],
#       dtype='object')

# %%
data.nunique()
# Out:
# PoB                                23
# PoB Office                          7
# PoB Online / Offline Countries      2
# PoB Countries                      23
# Month                              12
# Period                              2
# Carrier                             2
# Contribution                        2
# NTR EUR 2022                      635
# NTR BGT 2022                      592
# PaxKM EUR 2022                    633
# PaxKM BGT 2022                    585
# dtype: int64

# %%
#cleaning the data

# %%
data.isnull().sum()
# Out:
# PoB                               0
# PoB Office                        0
# PoB Online / Offline Countries    0
# PoB Countries                     0
# Month                             0
# Period                            0
# Carrier                           0
# Contribution                      0
# NTR EUR 2022                      0
# NTR BGT 2022                      0
# PaxKM EUR 2022                    0
# PaxKM BGT 2022                    0
# dtype: int64

# %%
SALESDATAA = data.drop(['PoB','PoB Office','PoB Online / Offline Countries','PoB Countries','Period','Contribution','Month','Carrier'], axis=1)

# %%
SALESDATAA.head()
# Out:
#    NTR EUR 2022  NTR BGT 2022  PaxKM EUR 2022  PaxKM BGT 2022
# 0        100761        135853          467398          510334
# 1        269144        484569         4174734         5313041
# 2             0             0               0               0
# 3           216             0            4876               0
# 4        221642        226573          872608          682672

# %%
#3 relationship analysis

# %%
corelation = SALESDATAA.corr()

# %%
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(SALESDATAA)

# %%
sns.relplot(x= 'NTR EUR 2022', y='NTR BGT 2022', hue='PaxKM EUR 2022', data=SALESDATAA)

# %%
sns.distplot(SALESDATAA['NTR EUR 2022'])
# Out:
# C:\Users\BRUTUS\AppData\Local\Temp\ipykernel_12984\1735131308.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(SALESDATAA['NTR EUR 2022'])
# <Axes: xlabel='NTR EUR 2022', ylabel='Density'>

# %%
sns.distplot(SALESDATAA['NTR BGT 2022'])
# Out:
# C:\Users\BRUTUS\AppData\Local\Temp\ipykernel_12984\3811432733.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(SALESDATAA['NTR BGT 2022'])
# <Axes: xlabel='NTR BGT 2022', ylabel='Density'>

# %%
sns.distplot(SALESDATAA['PaxKM EUR 2022'])
# Out:
# C:\Users\BRUTUS\AppData\Local\Temp\ipykernel_12984\3762216545.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(SALESDATAA['PaxKM EUR 2022'])
# <Axes: xlabel='PaxKM EUR 2022', ylabel='Density'>

# %%
sns.distplot(SALESDATAA['PaxKM BGT 2022'])
# Out:
# C:\Users\BRUTUS\AppData\Local\Temp\ipykernel_12984\505380832.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(SALESDATAA['PaxKM BGT 2022'])
# <Axes: xlabel='PaxKM BGT 2022', ylabel='Density'>
